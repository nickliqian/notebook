# %%
print("test")
# Out:
# test

# %%
# load dataset
mydf=sjs_load_data.load_data_set(44)
mydf
# Out:
# [INFO] Get Source Id:<44> for data source connection info
# [INFO] Data Type:<MySQL> Source Id:<44>
# [INFO] Config: 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
# load dataset
mydf=sjs_load_data.load_data_set(44)
# Out:
# get <source_id:44> source connection info
# data_type:MySQL source_id:44
# 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
dff = pd.DataFrame(np.random.randint(50, size=(10, 2)), index=list(range(10)), columns=["day_1", "day_2"])

# %%
# Draw Bar
draw_bar(dff,y_field="day_1")

# %%
# Draw Bar
draw_bar(dff,x_field="day_1",y_field="day_2")

# %%
# Draw Box

# %%
# Draw Box
draw_box(dff,value_field="day_1")

# %%
# Draw Box

# %%
# Draw Points
draw_points(dff,y_field="day_2")

# %%
# Draw Points
draw_points(dff,x_field="day_1",y_field="day_2")

# %%
# Draw Lines
draw_lines(dff,y_field="day_2")

# %%
# Draw Lines
draw_lines(dff,x_field="day_1",y_field="day_2")

# %%
# load dataset
mydf=load_data_set(44)
# Out:
# get <source_id:44> source connection info
# data_type:MySQL source_id:44
# 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
# load dataset
mydf=load_data_set(44)
# Out:
# get <source_id:44> source connection info
# data_type:MySQL source_id:44
# 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
mydf
# Out:
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
dff = pd.DataFrame(np.random.randint(50, size=(10, 2)), index=list(range(10)), columns=["day_1", "day_2"])

# %%
dff
# Out:
#    day_1  day_2
# 0      2     15
# 1     46     15
# 2     17      6
# 3     43     45
# 4     39     38
# 5     22     47
# 6     35      0
# 7     14     29
# 8      5     26
# 9     28     35

# %%
# Draw Bar
draw_bar(dff,y_field="day_2")

# %%
# Draw Bar
draw_bar(dff,x_field="day_1",y_field="day_2")

# %%
# Draw Box
draw_box(dff,value_field="day_1")

# %%
# Draw Hist
draw_hist(dff,y_field="day_2",bins="[0, 18, 37, 50, 95]",rwidth="0.8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-03f8dd690db5> in <module>()
#       1 # Draw Hist
# ----> 2 draw_hist(dff,y_field="day_2",bins="[0, 18, 37, 50, 95]",rwidth="0.8")
#
# TypeError: draw_hist() got an unexpected keyword argument 'y_field'

# %%
# Draw Hist
draw_hist(dff,value_field="day_1",bins="[0, 18, 37, 50, 95]",rwidth="0.8")

# %%
# load dataset
mydf=load_data_set(44)
# Out:
# get <source_id:44> source connection info
# data_type:MySQL source_id:44
# 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
mydf
# Out:
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
# Draw Bar
draw_bar(mydf,y_field="day_1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\pyinstall\virset\virpy360set\jup\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-4ba9309749de> in <module>()
#       1 # Draw Bar
# ...

# %%
# Draw Bar
draw_bar(dff,y_field="day_1")

# %%
print(123)
# Out:
# 123

# %%
# load dataset
mydf=sjs_load_data.load_data_set(44)
# Out:
# get <source_id:44> source connection info
# data_type:MySQL source_id:44
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-37c0363b2491> in <module>()
#       1 # load dataset
# ----> 2 mydf=sjs_load_data.load_data_set(44)
#
# ~\.ipython\profile_default\startup\00-dataset_api.py in load_data_set(self, source_id)
#      38             pass
#      39         elif data_type == "mysql":
# ---> 40             df = self.read_mysql(config_data)
#      41         elif data_type == "hbase":
#      42             pass
#
# ~\.ipython\profile_default\startup\00-dataset_api.py in read_mysql(config_data)
#     100         # 获取数据
#     101         conn_params = config_data["connParams"]
# --> 102         conn_url = conn_params["url"]
#     103         # 解析数据
#     104         host = re.findall(r"://(.*?):", conn_url)[0]
#
# TypeError: string indices must be integers

# %%
# load dataset
mydf=sjs_load_data.load_data_set(44)
# Out:
# get <source_id:44> source connection info
# data_type:MySQL source_id:44
# 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
mydf
# Out:
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
# load dataset
mydf=sjs_load_data.load_data_set(51)
# Out:
# get <source_id:51> source connection info
# data_type:MySQL source_id:51
# 192.168.10.204 3306 fenxi fenxi@123 cubo notebook_test
#    id  name  age       city
# 0   1  Alan   25    beijing
# 1   2  Hank   22  chongqing

# %%
# load dataset
mydf=sjs_load_data.load_data_set(45)
mydf
# Out:
# [INFO] Get Source Id:<45> for data source connection info
# [INFO] Data Type:<SQLServer> Source Id:<45>
# [INFO] Config: 192.168.10.58 1433 fenxi Fenxi@123 my_sql_server user_info
#    user_id user_name  age
# 0        1  zhangsan   20
# 1        2        李四   23
# 2        3        王五   25
