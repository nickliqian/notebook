# %%
params = dict(
    model="qwe",
    train="sdf",
    test="dsg",
    label="a",
    path="f",
)
params

# %%
params = dict(
    train="qwe",
    test="qwr",
    label="sd",
    algo="sf",
    path="a",
)
params

# %%
params = dict(
    dataframe="23",
    to_select="34",
    label="34",
    feature="34",
    estimator="2",
)
params

# %%
params = dict(
    dataframe="23",
    variable="23423",
    label="234",
    no_default=23,
    default=23,
    bins=23
)
params

# %%
params = dict(
    dataframe="23",
    ratio="34",
    seed="23",
)
params

# %%
params = dict(
dataframe="1",
variable="2",
label="3",
no_default=4,
default=5,
bins=6
)
params
